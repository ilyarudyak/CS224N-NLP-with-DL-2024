# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

# %% [markdown]
# ## 01 The First Run on a Toy Dataset

# %%
# !python run.py train \
    --train-src=zh_en_data/train_1K.zh \
    --train-tgt=zh_en_data/train_1K.en \
    --dev-src=zh_en_data/dev_100.zh \
    --dev-tgt=zh_en_data/dev_100.en \
    --vocab=vocab.json \
    --mps \
    --embed-size=128 \
    --hidden-size=128 \
    --batch-size=8 \
    --max-epoch=1 \
    --valid-niter=20 \
    --log-every=5 \
    --max-decoding-time-step=20 \
    --dropout=0.0 \
    --save-to=toy_model.bin
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/iliarudiak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: mps
# begin Maximum Likelihood training
# /Users/iliarudiak/Library/Mobile Documents/com~apple~CloudDocs/_working/2026/env/lib/python3.14/site-packages/torch/nn/modules/conv.py:380: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1091.)
#   return F.conv1d(
# epoch 1, iter 5, avg. loss 8.93, avg. ppl 7587.03 cum. examples 40, speed 156.16 words/sec, time elapsed 6.76 sec
# epoch 1, iter 10, avg. loss 8.52, avg. ppl 4996.90 cum. examples 80, speed 1248.39 words/sec, time elapsed 7.56 sec
# epoch 1, iter 15, avg. loss 7.82, avg. ppl 2485.88 cum. examples 120, speed 1514.90 words/sec, time elapsed 8.25 sec
# epoch 1, iter 20, avg. loss 7.24, avg. ppl 1395.17 cum. examples 160, speed 968.82 words/sec, time elapsed 9.31 sec
# epoch 1, iter 20, cum. loss 8.13, cum. ppl 3391.43 cum. examples 160
# begin validation ...
# Decoding: 100%|███████████████████████████████████| 1/1 [00:03<00:00,  3.05s/it]
# validation: iter 20, dev. ppl 1210.674169
# save currently the best model to [toy_model.bin]
# save model parameters to [toy_model.bin]
# reached maximum number of epochs!

# %%
from pathlib import Path

for filename in [
    "zh_en_data/train_1K.zh",
    "zh_en_data/train_1K.en",
    "zh_en_data/dev_100.zh",
    "zh_en_data/dev_100.en",
]:
    path = Path(filename)
    print(f"{filename}: {sum(1 for _ in path.open(encoding='utf-8'))} lines")
# Out:
# zh_en_data/train_1K.zh: 1000 lines
# zh_en_data/train_1K.en: 1000 lines
# zh_en_data/dev_100.zh: 100 lines
# zh_en_data/dev_100.en: 100 lines

# %%
# !python run.py train \
    --train-src=zh_en_data/train_1K.zh \
    --train-tgt=zh_en_data/train_1K.en \
    --dev-src=zh_en_data/dev_100.zh \
    --dev-tgt=zh_en_data/dev_100.en \
    --vocab=vocab.json \
    --mps \
    --embed-size=128 \
    --hidden-size=128 \
    --batch-size=8 \
    --max-epoch=1 \
    --valid-niter=125 \
    --log-every=25 \
    --max-decoding-time-step=20 \
    --dropout=0.0 \
    --save-to=toy_model.bin
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/iliarudiak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: mps
# begin Maximum Likelihood training
# /Users/iliarudiak/Library/Mobile Documents/com~apple~CloudDocs/_working/2026/env/lib/python3.14/site-packages/torch/nn/modules/conv.py:380: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1091.)
#   return F.conv1d(
# epoch 1, iter 25, avg. loss 7.90, avg. ppl 2709.32 cum. examples 200, speed 1363.39 words/sec, time elapsed 3.85 sec
# epoch 1, iter 50, avg. loss 6.88, avg. ppl 973.56 cum. examples 400, speed 1609.21 words/sec, time elapsed 7.12 sec
# epoch 1, iter 75, avg. loss 6.88, avg. ppl 967.97 cum. examples 600, speed 1690.98 words/sec, time elapsed 10.24 sec
# epoch 1, iter 100, avg. loss 6.76, avg. ppl 864.31 cum. examples 800, speed 2433.22 words/sec, time elapsed 12.43 sec
# epoch 1, iter 125, avg. loss 6.72, avg. ppl 826.97 cum. examples 1000, speed 2273.12 words/sec, time elapsed 14.77 sec
# epoch 1, iter 125, cum. loss 7.03, cum. ppl 1125.86 cum. examples 1000
# begin validation ...
# Decoding: 100%|███████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# validation: iter 125, dev. ppl 791.377200
# save currently the best model to [toy_model.bin]
# save model parameters to [toy_model.bin]
# reached maximum number of epochs!

# %%
# !bash train_toy_mps.sh
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/iliarudiak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: mps
# begin Maximum Likelihood training
# /Users/iliarudiak/Library/Mobile Documents/com~apple~CloudDocs/_working/2026/env/lib/python3.14/site-packages/torch/nn/modules/conv.py:380: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1091.)
#   return F.conv1d(
# epoch 1, iter 25, avg. loss 7.90, avg. ppl 2709.32 cum. examples 200, speed 1523.59 words/sec, time elapsed 3.45 sec
# epoch 1, iter 50, avg. loss 6.88, avg. ppl 973.56 cum. examples 400, speed 2270.79 words/sec, time elapsed 5.76 sec
# epoch 1, iter 75, avg. loss 6.88, avg. ppl 967.97 cum. examples 600, speed 2476.69 words/sec, time elapsed 7.89 sec
# epoch 1, iter 100, avg. loss 6.76, avg. ppl 864.30 cum. examples 800, speed 2370.52 words/sec, time elapsed 10.14 sec
# epoch 1, iter 125, avg. loss 6.72, avg. ppl 827.13 cum. examples 1000, speed 2021.41 words/sec, time elapsed 12.77 sec
# epoch 1, iter 125, cum. loss 7.03, cum. ppl 1125.91 cum. examples 1000
# begin validation ...
# Decoding: 100%|███████████████████████████████████| 1/1 [00:00<00:00,  1.75it/s]
# validation: iter 125, dev. ppl 791.389276
# save currently the best model to [toy_model.bin]
# save model parameters to [toy_model.bin]
# reached maximum number of epochs!
