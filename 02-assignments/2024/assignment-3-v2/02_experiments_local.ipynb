# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

# %% [markdown]
# ## 01 Verify Toy Dataset Files

# %%
for filename in [
    "zh_en_data/train_1K.zh",
    "zh_en_data/train_1K.en",
    "zh_en_data/dev_100.zh",
    "zh_en_data/dev_100.en",
]:
    path = Path(filename)
    print(f"{filename}: {sum(1 for _ in path.open(encoding='utf-8'))} lines")
# Out:
# zh_en_data/train_1K.zh: 1000 lines
# zh_en_data/train_1K.en: 1000 lines
# zh_en_data/dev_100.zh: 100 lines
# zh_en_data/dev_100.en: 100 lines

# %% [markdown]
# ## 02 The First Run on a Toy Dataset (Local MPS / CPU)
#
# Tests `TranslationDataset`, `TranslationCollate`, and the updated `nmt_model.py` with PyTorch `DataLoader`.

# %%
# !python run.py train \
    --train-src=zh_en_data/train_1K.zh \
    --train-tgt=zh_en_data/train_1K.en \
    --dev-src=zh_en_data/dev_100.zh \
    --dev-tgt=zh_en_data/dev_100.en \
    --vocab=vocab.json \
    --mps \
    --embed-size=128 \
    --hidden-size=128 \
    --batch-size=8 \
    --max-epoch=1 \
    --valid-niter=25 \
    --log-every=5 \
    --max-decoding-time-step=20 \
    --dropout=0.0 \
    --save-to=toy_model.bin
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/iliarudiak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# loading training dataset...
# loading dev dataset...
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: mps
# begin Maximum Likelihood training
# /Users/iliarudiak/Library/Mobile Documents/com~apple~CloudDocs/_working/2026/env/lib/python3.14/site-packages/torch/nn/modules/conv.py:380: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1091.)
#   return F.conv1d(
# epoch 1, iter 5, avg. loss 8.94, avg. ppl 7594.84 cum. examples 40, speed 149.11 words/sec, time elapsed 7.42 sec
# epoch 1, iter 10, avg. loss 6.63, avg. ppl 759.91 cum. examples 80, speed 759.23 words/sec, time elapsed 8.80 sec
# epoch 1, iter 15, avg. loss 7.87, avg. ppl 2622.97 cum. examples 120, speed 1301.80 words/sec, time elapsed 9.61 sec
# epoch 1, iter 20, avg. loss 7.36, avg. ppl 1579.16 cum. examples 160, speed 2192.83 words/sec, time elapsed 10.09 sec
# epoch 1, iter 25, avg. loss 7.06, avg. ppl 1169.34 cum. examples 200, speed 2388.79 words/sec, time elapsed 10.53 sec
# epoch 1, iter 25, cum. loss 7.59, cum. ppl 1972.83 cum. examples 200
# begin validation ...
# Decoding: 100%|███████████████████████████████████| 1/1 [00:03<00:00,  3.78s/it]
# validation: iter 25, dev. ppl 1032.982350
# save currently the best model to [toy_model.bin]
# save model parameters to [toy_model.bin]
# reached maximum number of epochs!

# %% [markdown]
# ## 03 Decode Using the Trained Toy Model

# %%
# !python run.py decode \
    toy_model.bin \
    ./zh_en_data/dev_100.zh \
    ./zh_en_data/dev_100.en \
    outputs/toy_dev_outputs.txt \
    --mps
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/iliarudiak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# load test source sentences from [./zh_en_data/dev_100.zh]
# load test target sentences from [./zh_en_data/dev_100.en]
# load model from toy_model.bin
# Decoding:   0%|                                         | 0/100 [00:00<?, ?it/s]/Users/iliarudiak/Library/Mobile Documents/com~apple~CloudDocs/_working/2026/env/lib/python3.14/site-packages/torch/nn/modules/conv.py:380: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1091.)
#   return F.conv1d(
# Decoding: 100%|███████████████████████████████| 100/100 [00:31<00:00,  3.15it/s]
# Corpus BLEU: 0.0

# %%
# !head -n 5 outputs/toy_dev_outputs.txt
